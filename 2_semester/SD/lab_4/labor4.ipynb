# %%
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t) == x+4*y
deq2 = diff(y,t) == x+y
syst=[deq1,deq2]

# %%
desolve_system(syst, [x,y])
# Out:
# [x(t) == 1/2*(x(0) + 2*y(0))*e^(3*t) + 1/2*(x(0) - 2*y(0))*e^(-t),
#  y(t) == 1/4*(x(0) + 2*y(0))*e^(3*t) - 1/4*(x(0) - 2*y(0))*e^(-t)]

# %%
C1,C2=var('C1,C2')
desolve_system(syst, [x,y], [0,C1,C2])
# Out:
# [x(t) == 1/2*(C1 + 2*C2)*e^(3*t) + 1/2*(C1 - 2*C2)*e^(-t),
#  y(t) == 1/4*(C1 + 2*C2)*e^(3*t) - 1/4*(C1 - 2*C2)*e^(-t)]

# %%
sol = desolve_system(syst, [x,y], [0,C1,C2])
sol_x(t,C1,C2)=sol[0].rhs()
sol_x
# Out:
# (t, C1, C2) |--> 1/2*(C1 + 2*C2)*e^(3*t) + 1/2*(C1 - 2*C2)*e^(-t)

# %%
sol_y(t,C1,C2) = sol[1].rhs()
sol_y
# Out:
# (t, C1, C2) |--> 1/4*(C1 + 2*C2)*e^(3*t) - 1/4*(C1 - 2*C2)*e^(-t)

# %%
plot(sol_x(t,2,2),t,-3,3,ymin=-10,ymax=10,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t,2,2),t,-3,3,ymin=-10,ymax=10,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g1=plot(sol_x(t,1,1),t,-4,4,ymin=-10,ymax=10,color='blue')
g2=plot(sol_y(t,1,1),t,-4,4,ymin=-10,ymax=10,color='red')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
reset()
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1=diff(x,t)==2*x-y
deq2=diff(y,t)==x+2*y
syst=[deq1,deq2]
desolve_system(syst, [x,y])
# Out:
# [x(t) == -(C2*sin(t) - cos(t)*x(0))*e^(2*t),
#  y(t) == (C2*cos(t) + sin(t)*x(0))*e^(2*t)]

# %%
C1,C2=var('C1,C2')
desolve_system(syst, [x,y],[0,C1,C2])
# Out:
# [x(t) == (C1*cos(t) - C2*sin(t))*e^(2*t),
#  y(t) == (C2*cos(t) + C1*sin(t))*e^(2*t)]

# %%
sol=desolve_system(syst, [x,y],[0,C1,C2])
sol_x(t,C1,C2)=sol[0].rhs()
sol_x
# Out:
# (t, C1, C2) |--> (C1*cos(t) - C2*sin(t))*e^(2*t)

# %%
sol=desolve_system(syst, [x,y],[0,C1,C2])
sol_y(t,C1,C2)=sol[1].rhs()
sol_y
# Out:
# (t, C1, C2) |--> (C2*cos(t) + C1*sin(t))*e^(2*t)

# %%
plot(sol_x(t,2,2),t,-5,5,ymin=-10,ymax=10,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t,2,2),t,-5,5,ymin=-10,ymax=10,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g1=plot(sol_x(t,1,1),t,-4,4,color='red')
g2=plot(sol_y(t,1,1),t,-4,4,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
reset()
t = var('t')
x=function('x')(t)
y=function('y')(t)
z=function('z')(t)
deq1=diff(x,t)==x-y+z
deq2=diff(y,t)==x+y-z
deq3=diff(z,t)==-y+2*z
syst=[deq1,deq2,deq3]
desolve_system(syst,[x,y,z])
# Out:
# [x(t) == t*e^t*x(0) - t*e^t*z(0) - (C2 + x(0) - 2*z(0))*e^(2*t) + (C2 + 2*x(0) - 2*z(0))*e^t,
#  y(t) == t*e^t*x(0) - t*e^t*z(0) + C2*e^t,
#  z(t) == t*e^t*x(0) - t*e^t*z(0) - (C2 + x(0) - 2*z(0))*e^(2*t) + (C2 + x(0) - z(0))*e^t]

# %%
C1,C2,C3=var('C1,C2,C3')
desolve_system(syst, [x,y,z],[0,C1,C2,C3])
# Out:
# [x(t) == C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (2*C1 + C2 - 2*C3)*e^t,
#  y(t) == C1*t*e^t - C3*t*e^t + C2*e^t,
#  z(t) == C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (C1 + C2 - C3)*e^t]

# %%
sol=desolve_system(syst, [x,y,z],[0,C1,C2,C3])
sol_x(t,C1,C2,C3)=sol[0].rhs()
sol_x
# Out:
# (t, C1, C2, C3) |--> C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (2*C1 + C2 - 2*C3)*e^t

# %%
sol=desolve_system(syst, [x,y,z],[0,C1,C2,C3])
sol_y(t,C1,C2,C3)=sol[1].rhs()
sol_y
# Out:
# (t, C1, C2, C3) |--> C1*t*e^t - C3*t*e^t + C2*e^t

# %%
sol=desolve_system(syst, [x,y,z],[0,C1,C2,C3])
sol_z(t,C1,C2,C3)=sol[2].rhs()
sol_z
# Out:
# (t, C1, C2, C3) |--> C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (C1 + C2 - C3)*e^t

# %%
g1=plot(sol_x(t,1,1,1),t,-4,4,color='red')
g2=plot(sol_y(t,1,1,1),t,-4,4,color='blue')
g3=plot(sol_z(t,1,1,1),t,-4,4,color='yellow')
show(g1+g2+g3)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
reset()
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1=diff(x,t)==5*x+3*y+1
deq2=diff(y,t)==(-6)*x-4*y+exp(-t)
syst=[deq1,deq2]
desolve_system(syst, [x,y])
# Out:
# [x(t) == 1/3*(3*C2 + 6*x(0) + 4)*e^(2*t) - 1/3*(3*C2 + 3*x(0) - 2)*e^(-t) - t*e^(-t) - 2,
#  y(t) == -1/3*(3*C2 + 6*x(0) + 4)*e^(2*t) + 1/3*(6*C2 + 6*x(0) - 5)*e^(-t) + 2*t*e^(-t) + 3]

# %%
C1,C2=var('C1,C2')
sol=desolve_system(syst, [x,y],[0,C1,C2])
sol_x(t,C1,C2)=sol[0].rhs()
sol_x
# Out:
# (t, C1, C2) |--> 1/3*(6*C1 + 3*C2 + 4)*e^(2*t) - 1/3*(3*C1 + 3*C2 - 2)*e^(-t) - t*e^(-t) - 2

# %%
sol=desolve_system(syst, [x,y],[0,C1,C2])
sol_y(t,C1,C2)=sol[1].rhs()
sol_y
# Out:
# (t, C1, C2) |--> -1/3*(6*C1 + 3*C2 + 4)*e^(2*t) + 1/3*(6*C1 + 6*C2 - 5)*e^(-t) + 2*t*e^(-t) + 3

# %%
g1=plot(sol_x(t,1,1),t,-4,4,color='red')
g2=plot(sol_y(t,1,1),t,-4,4,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
reset()

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+4*y
deq2=diff(y,t)==x+y
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,1,2]

# %%
sol = desolve_system(syst,vars,in_cond)
sol
# Out:
# [x(t) == 5/2*e^(3*t) - 3/2*e^(-t), y(t) == 5/4*e^(3*t) + 3/4*e^(-t)]

# %%
sol_x(t)=sol[0].rhs()
sol_x
# Out:
# t |--> 5/2*e^(3*t) - 3/2*e^(-t)

# %%
sol_y(t)=sol[1].rhs()
sol_y
# Out:
# t |--> 5/4*e^(3*t) + 3/4*e^(-t)

# %%
plot(sol_x(t),t,-4,4,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t),t,-4,4,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g1=plot(sol_x(t),t,-4,4,color='red')
g2=plot(sol_y(t),t,-4,4,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
reset()
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x-y+t-1
deq2=diff(y,t)==(-2)*x+4*y+cos(t)
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,0,1]
sol=desolve_system(syst, vars,in_cond)
sol
# Out:
# [x(t) == -1/13*(10*sqrt(17)*sinh(1/2*sqrt(17)*t) - 33*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - 2*t - 1/26*cos(t) + 5/26*sin(t) - 5/2,
#  y(t) == -1/26*(3*sqrt(17)*sinh(1/2*sqrt(17)*t) - 71*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - t - 3/13*cos(t) + 2/13*sin(t) - 3/2]

# %%
sol_x(t)=sol[0].rhs()
sol_x
# Out:
# t |--> -1/13*(10*sqrt(17)*sinh(1/2*sqrt(17)*t) - 33*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - 2*t - 1/26*cos(t) + 5/26*sin(t) - 5/2

# %%
sol_y(t)=sol[1].rhs()
sol_y
# Out:
# t |--> -1/26*(3*sqrt(17)*sinh(1/2*sqrt(17)*t) - 71*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - t - 3/13*cos(t) + 2/13*sin(t) - 3/2

# %%
g1=plot(sol_x(t),t,-4,4,color='red')
g2=plot(sol_y(t),t,-4,4,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
reset()
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+2*y+exp(-t)
deq2=diff(y,t)==(-2)*x+4*y+cos(t)
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,0,1]
sol=desolve_system(syst, vars,in_cond)
sol
# Out:
# [x(t) == 1/518*(349*sqrt(7)*sin(1/2*sqrt(7)*t) + 87*cos(1/2*sqrt(7)*t))*e^(5/2*t) + 7/37*cos(t) - 5/14*e^(-t) - 5/37*sin(t),
#  y(t) == 2/259*(60*sqrt(7)*sin(1/2*sqrt(7)*t) + 169*cos(1/2*sqrt(7)*t))*e^(5/2*t) - 6/37*cos(t) - 1/7*e^(-t) - 1/37*sin(t)]

# %%
sol_x(t)=sol[0].rhs()
sol_x
# Out:
# t |--> 1/518*(349*sqrt(7)*sin(1/2*sqrt(7)*t) + 87*cos(1/2*sqrt(7)*t))*e^(5/2*t) + 7/37*cos(t) - 5/14*e^(-t) - 5/37*sin(t)

# %%
sol_y(t)=sol[1].rhs()
sol_y
# Out:
# t |--> 2/259*(60*sqrt(7)*sin(1/2*sqrt(7)*t) + 169*cos(1/2*sqrt(7)*t))*e^(5/2*t) - 6/37*cos(t) - 1/7*e^(-t) - 1/37*sin(t)

# %%
g1=plot(sol_x(t),t,-4,4,color='red')
g2=plot(sol_y(t),t,-4,4,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
reset()
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==y
deq2=diff(y,t)==-x-2*y
syst=[deq1,deq2]
desolve_system(syst, [x,y])
# Out:
# [x(t) == t*e^(-t)*x(0) + t*e^(-t) + e^(-t)*x(0),
#  y(t) == -t*e^(-t)*x(0) - t*e^(-t) + e^(-t)]

# %%
C1,C2=var('C1,C2')
desolve_system(syst, [x,y],[0,C1,C2])
# Out:
# [x(t) == C1*t*e^(-t) + C2*t*e^(-t) + C1*e^(-t),
#  y(t) == -C1*t*e^(-t) - C2*t*e^(-t) + C2*e^(-t)]

# %%
sol=desolve_system(syst, [x,y],[0,C1,C2])
sol_x(t,C1,C2)=sol[0].rhs()
sol_x
# Out:
# (t, C1, C2) |--> C1*t*e^(-t) + C2*t*e^(-t) + C1*e^(-t)

# %%
sol=desolve_system(syst, [x,y],[0,C1,C2])
sol_y(t,C1,C2)=sol[1].rhs()
sol_y
# Out:
# (t, C1, C2) |--> -C1*t*e^(-t) - C2*t*e^(-t) + C2*e^(-t)

# %%
limit(sol_x, t = infinity)
# Out:
# (t, C1, C2) |--> 0

# %%
limit(sol_y, t = infinity)
# Out:
# (t, C1, C2) |--> 0

# %%
f1(u,v) = v
f2(u,v) = -u-2*v
plot_vector_field([f1(u,v),f2(u,v)], [u,-10,10], [v,-10,10])
# Out:
# Graphics object consisting of 1 graphics primitive
