# %%
x = var('x')
eq1 = x^2 - (3/2)*x^3 - x + 3/2 == 0
eq1
# Out:
# -3/2*x^3 + x^2 - x + 3/2 == 0

# %%
x = var('x')
eq1 = x^2 - (3/2)*x^3 - x + 3/2 == 0
eq1
# Out:
# -3/2*x^3 + x^2 - x + 3/2 == 0

# %%
solve(eq1, x)
# Out:
# [x == -1/6*I*sqrt(35) - 1/6, x == 1/6*I*sqrt(35) - 1/6, x == 1]

# %%
x = var('x')
eq1 = x^4 - 3/2*x^3 - x + 3/2 == 0
solve(eq1, x)
# Out:
# [x == 1, x == (3/2), x == -1/2*I*sqrt(3) - 1/2, x == 1/2*I*sqrt(3) - 1/2]

# %%
x = var('x')
eq2 = sqrt(x^2 + 2*x) == 3
solve(eq2, x)
# Out:
# [x == -sqrt(10) - 1, x == sqrt(10) - 1]

# %%
x, y = var('x', 'y')
syst1 = [2*x + y == 3, x + 3*y == -1]
solve(syst1, x, y)
# Out:
# [[x == 2, y == -1]]

# %%
syst2 = [2*x + x*y + 2*y == 59, 3*x - 2*x*y + 3*y == -34]
solve(syst2, x, y)
# Out:
# [[x == 7, y == 5], [x == 5, y == 7]]

# %%
limit(sin(x)/x, x = 0)
# Out:
# 1

# %%
f(x) = (x^3 + 3*x^2 - 5)/(2*x^3 - 7*x)
limit(f(x), x = 0)
# Out:
# Infinity

# %%
limit(f(x), x = infinity)
# Out:
# 1/2

# %%
f(x) = (cos(x) + 1)/(x - pi)
limit(f(x), x = pi)
# Out:
# 0

# %%
y(x) = 3 * x^3 + 2*x^2 - 5
diff(y(x), x)
# Out:
# 9*x^2 + 4*x

# %%
y(x) = sqrt(1 + x^4)
diff(y(x), x)
# Out:
# 2*x^3/sqrt(x^4 + 1)

# %%
y(x) = exp(x) * sin(x) * cos(x)
diff(y(x), x)
# Out:
# cos(x)^2*e^x + cos(x)*e^x*sin(x) - e^x*sin(x)^2

# %%
integrate(3*x^3 + 2*x^2 - 5, x, 0, 1)
# Out:
# -43/12

# %%
integrate(1/x^2, x, 1, infinity)
# Out:
# 1

# %%
integrate(exp(-x^2), x)
# Out:
# 1/2*sqrt(pi)*erf(x)

# %%
f(x) = exp(-x) - 1
plot(f(x), -2, 2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1(x) = (200*exp(0.5*x)) / (2 * (exp(0.5*x) - 1) + 100)
f2(x) = (200*exp(-0.5*x)) / (2 * (exp(-0.5*x) - 1) + 100)
plot([f1(x), f2(x)], 0, 50, color = ['red', 'blue'])
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
f(x) = x * sin(1/x)
plot(f(x), -3, 3)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t = var('t')
x(t) = (1 - cos(t)) * cos(t)
y(t) = (1 - cos(t)) * sin(t)
plot([x(t), y(t)], (t, 0, 2 * pi))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
x(t) = sin(3*t)*cos(t)
y(t) = sin(3*t)*sin(t)
plot([x(t), y(t)], (t, 0, 2*pi), color = ['#1CDCD0', '#EE1DB3'])
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
x(t) = t - sin(t)
y(t) = sin(3*t)*sin(t)
plot([x(t), y(t)], (t, 0, 6*pi), color = ['#D50C0C', '#6E20DF'])
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
x(t) = cos(t) + cos(7*t)/2 + sin(17*t)/3
y(t) = sin(t) + sin(7*t)/2 + cos(17*t)/3
plot([x(t), y(t)], (t, 0, 2 * pi))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
x, y = var('x', 'y')
f(x, y) = x**2 + y**2 - 2*x - 4*y + 4
implicit_plot = (f(x, y) == 0, (x, ))
