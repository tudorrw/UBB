# %%
x = var('x')
y = function('y')(x)
eqd = diff(y, x) - 2 * x * y == 0
desolve(eqd, y)
# Out:
# _C*e^(x^2)

# %%
desolve(eqd, y, show_method = True)
# Out:
# [_C*e^(x^2), 'linear']

# %%
sol = desolve(eqd, y)
_C = var('_C')
sol1 = sol.substitute(_C == 1)

# %%
plot(sol1,x,-3, 3)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x = var('x')
y = function('y')(x)
eqd = diff(y, x) == y/x
sol = desolve(eqd, y)
sol
# Out:
# _C*x

# %%
_C = var('_C')
sol2 = sol.substitute(_C == 1.5)
plot(sol2, x, -2, 2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x = var('x')
y = function('y')(x)
eqd = diff(x, y) == 2*x*(1 + y^2)
sol = desolve(eqd, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-26d22d487ac1> in <module>
#       1 x = var('x')
#       2 y = function('y')(x)
# ----> 3 eqd = diff(x, y) == Integer(2)*x*(Integer(1) + y**Integer(2))
#       4 sol = desolve(eqd, y)
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/calculus/functional.py in derivative(f, *args, **kwds)
#     148     """
#     149     try:
# --> 150         return f.derivative(*args, **kwds)
#     151     except AttributeError:
#     152         pass
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.derivative (build/cythonized/sage/symbolic/expression.cpp:26967)()
#    4324             ValueError: No differentiation variable specified.
#    4325         """
# -> 4326         return multi_derivative(self, args)
#    4327
#    4328     diff = differentiate = derivative
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/misc/derivative.pyx in sage.misc.derivative.multi_derivative (build/cythonized/sage/misc/derivative.c:3176)()
#     220
#     221     for arg in derivative_parse(args):
# --> 222         F = F._derivative(arg)
#     223     return F
#     224
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression._derivative (build/cythonized/sage/symbolic/expression.cpp:27449)()
#    4392         cdef Expression symbol = self.coerce_in(symb)
#    4393         if not is_a_symbol(symbol._gobj):
# -> 4394             raise TypeError("argument symb must be a symbol")
#    4395         cdef GEx x
#    4396         sig_on()
#
# TypeError: argument symb must be a symbol

# %%
x = var('x')
y = function('y')(x)
eqd = diff(y,x) == 2*x*(1 + y^2)
sol = desolve(eqd, y)
sol
# Out:
# 1/2*arctan(y(x)) == 1/2*x^2 + _C

# %%
yy = var('yy')
sol.substitute(y(x) == yy)
# Out:
# 1/2*arctan(yy) == 1/2*x^2 + _C

# %%
_C = var('_C')
f(x, yy, _C) = sol.substitute(y(x) == yy)
f(x, yy, _C)
# Out:
# 1/2*arctan(yy) == 1/2*x^2 + _C

# %%
implicit_plot(f(x, yy, 0), (x,-5, 5), (yy, -5, 5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x = var('x')
y = function('y')(x)
eqd = (x^2 - 1)*diff(y, x) + 2*x*(y^2) == 0
sol = desolve(eqd, y)
sol
# Out:
# 1/2/y(x) == _C + 1/2*log(x + 1) + 1/2*log(x - 1)

# %%
yy = var('yy')
f(x, yy, _C) = sol.substitute(y(x) == yy)
implicit_plot(f(x, yy, 0), (x, -5, 5), (yy, -5, 5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
v = var('x')
y = function('y')(x)
eqd = diff(y, x) + y*tan(x) == 1/cos(x)
sol = desolve(eqd, y)
sol
# Out:
# (_C + tan(x))/sec(x)

# %%
_C = var('_C')
sol4 = sol.substitute(_C == 1)
plot(sol4, x, -4, 4)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x = var('x')
y = function('y')(x)
eqd = diff(y, x) + (2/x)*y == x^3
sol = desolve(eqd, y)
sol
# Out:
# 1/6*(x^6 + 6*_C)/x^2

# %%
_C = var('_C')
sol5 = sol.substitute(_C == 1)
plot(sol5, x, 5, 10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x = var('x')
y = function('y')(x)
eqd = diff(y, x) + (1/x)*y == 3*x
sol = desolve(eqd, y)
sol
# Out:
# (x^3 + _C)/x

# %%
sol6 = sol.substitute(_C == 1)
plot(sol6, x, 2, 7)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
eqd = diff(y, x) == 1 + y^2
sol = desolve(eqd, y, ics = [0,1])
sol
# Out:
# arctan(y(x)) == 1/4*pi + x

# %%
plot(sol, x, -2, 2)
# Out:
# verbose 0 (3839: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 200 points.
# verbose 0 (3839: plot.py, generate_plot_points) Last error message: 'unable to simplify to float approximation'
# Graphics object consisting of 0 graphics primitives

# %%
yy = var('yy')
sol.substitute(y(x) == yy)
# Out:
# arctan(yy) == 1/4*pi + x

# %%
f(x, yy) = sol.substitute(y(x) == yy)
implicit_plot(f(x, yy, 0), (x, -4, 4), (yy, -4, 4))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
eqd = diff(y, x) - 2*y == -x^2 
sol = desolve(eqd, y, ics = [0,1/4])
sol
# Out:
# 1/2*x^2 + 1/2*x + 1/4

# %%
plot(sol,x, -4, 4)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x = var('x')
y = function('y')(x)
eqd = diff(y, x)-y*tan(x) == 1/cos(x)
sol = desolve(eqd, y, ics = [0, 0])
plot(sol, x, 0, 10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,k = var('x,k')
y = function('y')(x)
eqd = diff(y, x) + (k/x)*y == x**3
desolve(eqd, [y, x])
# Out:
# (x^4*x^k/(k + 4) + _C)/x^k

# %%
_C = var('_C')
sol = desolve(eqd, [y, x])
sol1 = sol.substitute(_C == 1, k == 1)
plot(sol1,x, -1, 1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
sol = desolve(eqd, [y, x], ics = [1, 0])
sol
# Out:
# (x^4*x^k - 1)/((k + 4)*x^k)

# %%
sol1 = sol.substitute(_C == 1, k == 1)
plot(sol1,x, -1, 1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x = var('x')
y = function('y')(x)
eqd = diff(y, x) - (1/2)*y == cos(x)
sol = desolve(eqd, y)
sol
# Out:
# -1/5*(2*(cos(x) - 2*sin(x))*e^(-1/2*x) - 5*_C)*e^(1/2*x)

# %%
_C = var('_C')
sol5 = sol.substitute(_C == 1)
sol5
# Out:
# -1/5*(2*(cos(x) - 2*sin(x))*e^(-1/2*x) - 5)*e^(1/2*x)

# %%
plot(sol5, x, -3,3)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x = var('x')
y = function('y')(x)
eqd = diff(y, x) - (1/2)*y == cos(x)
sol = desolve(eqd, y, ics = [0,1])
sol
# Out:
# -2/5*cos(x) + 7/5*e^(1/2*x) + 4/5*sin(x)

# %%
sol = desolve(eqd, y, ics = [0,5])
sol
# Out:
# -2/5*cos(x) + 27/5*e^(1/2*x) + 4/5*sin(x)

# %%
a = var('a')
sol = desolve(eqd, y, ics = [0,a])
sol
# Out:
# 1/5*(5*a + 2)*e^(1/2*x) - 2/5*cos(x) + 4/5*sin(x)
